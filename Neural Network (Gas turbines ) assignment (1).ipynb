# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('gas_turbines.csv')
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
df.isna().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %% [markdown]
# # correlation matrix

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df.AT)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AT', ylabel='Density'>

# %%
sns.distplot(df.AP)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AP', ylabel='Density'>

# %%
sns.distplot(df.AH)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AH', ylabel='Density'>

# %%
sns.distplot(df.AFDP)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AFDP', ylabel='Density'>

# %%
sns.distplot(df.GTEP)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GTEP', ylabel='Density'>

# %%
sns.distplot(df.TIT)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TIT', ylabel='Density'>

# %%
sns.distplot(df.TAT)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TAT', ylabel='Density'>

# %%
sns.distplot(df.TEY)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TEY', ylabel='Density'>

# %%
sns.distplot(df.CDP)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CDP', ylabel='Density'>

# %%
sns.distplot(df.CO)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CO', ylabel='Density'>

# %%
sns.distplot(df.NOX)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NOX', ylabel='Density'>

# %% [markdown]
# # Independent and dependent variables

# %%
df["TEy"] = 1
df.loc[df["TEY"] > 135,"TEy"] = 2
df.drop(["TEY"],axis = 1,inplace = True)

# %%
x=np.array(df.iloc[:,0:10])
x
# Out:
# array([[   6.8594, 1007.9   ,   96.799 , ...,   10.605 ,    3.1547,
#           82.722 ],
#        [   6.785 , 1008.4   ,   97.118 , ...,   10.598 ,    3.2363,
#           82.776 ],
#        [   6.8977, 1008.8   ,   95.939 , ...,   10.601 ,    3.2012,
#           82.468 ],
#        ...,
#        [   7.2647, 1006.3   ,   99.496 , ...,   10.483 ,    7.9632,
#           90.912 ],
#        [   7.006 , 1006.8   ,   99.008 , ...,   10.533 ,    6.2494,
#           93.227 ],
#        [   6.9279, 1007.2   ,   97.533 , ...,   10.583 ,    4.9816,
#           92.498 ]])

# %%
y=np.array(df.iloc[:,10])
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# # Normalize data

# %%
from sklearn.model_selection import train_test_split
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_norm = norm_func(x)
x_norm
# Out:
# array([[0.00623094, 0.9156068 , 0.08793482, ..., 0.00963355, 0.00286547,
#         0.07514684],
#        [0.00616335, 0.91606102, 0.08822461, ..., 0.00962719, 0.0029396 ,
#         0.0751959 ],
#        [0.00626573, 0.91642439, 0.08715357, ..., 0.00962992, 0.00290772,
#         0.0749161 ],
#        ...,
#        [0.00659912, 0.91415331, 0.09038485, ..., 0.00952273, 0.00723366,
#         0.08258689],
#        [0.00636411, 0.91460753, 0.08994154, ..., 0.00956815, 0.00567679,
#         0.0846899 ],
#        [0.00629316, 0.9149709 , 0.08860161, ..., 0.00961357, 0.00452509,
#         0.08402766]])

# %%
# Splitting data
x_train,x_test,y_train,y_test = train_test_split(x_norm,y, test_size = 0.2)

# %% [markdown]
# # Neural Network

# %%
import keras.models
import tensorflow
from tensorflow.keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model

# %%
# fix random seed for reproducibility
seed=7
np.random.seed(seed)

# %%
model.add(Dense(8, input_dim = 10, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(4,  kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1,  kernel_initializer = 'uniform', activation = 'linear'))

# %%
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(x_train,y_train, validation_split = 0.3, epochs = 20, batch_size = 10)
# Out:
# Epoch 1/20
# 843/843 [==============================] - 6s 4ms/step - loss: 0.5292 - accuracy: 0.5474 - val_loss: 0.2069 - val_accuracy: 0.7047
# Epoch 2/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.2079 - accuracy: 0.7023 - val_loss: 0.2083 - val_accuracy: 0.7047
# Epoch 3/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.2070 - accuracy: 0.7023 - val_loss: 0.2053 - val_accuracy: 0.7047
# Epoch 4/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.2059 - accuracy: 0.7023 - val_loss: 0.2050 - val_accuracy: 0.7047
# Epoch 5/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.2051 - accuracy: 0.7023 - val_loss: 0.2036 - val_accuracy: 0.7047
# Epoch 6/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.2037 - accuracy: 0.7023 - val_loss: 0.2022 - val_accuracy: 0.7047
# Epoch 7/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.2028 - accuracy: 0.7023 - val_loss: 0.2015 - val_accuracy: 0.7047
# Epoch 8/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.2013 - accuracy: 0.7023 - val_loss: 0.1995 - val_accuracy: 0.7047
# Epoch 9/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.1998 - accuracy: 0.7023 - val_loss: 0.1983 - val_accuracy: 0.7047
# Epoch 10/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.1983 - accuracy: 0.7023 - val_loss: 0.1970 - val_accuracy: 0.7047
# Epoch 11/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1962 - accuracy: 0.7023 - val_loss: 0.1948 - val_accuracy: 0.7047
# Epoch 12/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1942 - accuracy: 0.7023 - val_loss: 0.1927 - val_accuracy: 0.7047
# Epoch 13/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1917 - accuracy: 0.7023 - val_loss: 0.1895 - val_accuracy: 0.7047
# Epoch 14/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1887 - accuracy: 0.7023 - val_loss: 0.1865 - val_accuracy: 0.7047
# Epoch 15/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1852 - accuracy: 0.7023 - val_loss: 0.1833 - val_accuracy: 0.7047
# Epoch 16/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1809 - accuracy: 0.7023 - val_loss: 0.1782 - val_accuracy: 0.7047
# Epoch 17/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1760 - accuracy: 0.7023 - val_loss: 0.1742 - val_accuracy: 0.7047
# Epoch 18/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1697 - accuracy: 0.7023 - val_loss: 0.1663 - val_accuracy: 0.7047
# Epoch 19/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1623 - accuracy: 0.7023 - val_loss: 0.1587 - val_accuracy: 0.7047
# Epoch 20/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1536 - accuracy: 0.7019 - val_loss: 0.1493 - val_accuracy: 0.7047

# %%
score = model.evaluate(x_train, y_train)
score
# Out:
# 376/376 [==============================] - 2s 2ms/step - loss: 0.1485 - accuracy: 0.7027
# [0.1484503597021103, 0.702684760093689]

# %%
scores = model.evaluate(x_test, y_test)
scores
# Out:
# 94/94 [==============================] - 0s 3ms/step - loss: 0.1487 - accuracy: 0.7031
# [0.14872118830680847, 0.703125]

# %% [markdown]
# # visualise of training history

# %%
history = model.fit(x_train,y_train, validation_split = 0.3, epochs = 20, batch_size = 10)
# Out:
# Epoch 1/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1437 - accuracy: 0.7016 - val_loss: 0.1392 - val_accuracy: 0.7044
# Epoch 2/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1330 - accuracy: 0.7007 - val_loss: 0.1283 - val_accuracy: 0.7044
# Epoch 3/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1229 - accuracy: 0.7002 - val_loss: 0.1197 - val_accuracy: 0.7042
# Epoch 4/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1142 - accuracy: 0.6996 - val_loss: 0.1111 - val_accuracy: 0.7025
# Epoch 5/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1076 - accuracy: 0.6974 - val_loss: 0.1059 - val_accuracy: 0.6997
# Epoch 6/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.1034 - accuracy: 0.6955 - val_loss: 0.1025 - val_accuracy: 0.6970
# Epoch 7/20
# 843/843 [==============================] - 4s 5ms/step - loss: 0.1005 - accuracy: 0.6945 - val_loss: 0.1000 - val_accuracy: 0.6970
# Epoch 8/20
# 843/843 [==============================] - 3s 4ms/step - loss: 0.0983 - accuracy: 0.6918 - val_loss: 0.0991 - val_accuracy: 0.6970
# Epoch 9/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0916 - accuracy: 0.6958 - val_loss: 0.0838 - val_accuracy: 0.7044
# Epoch 10/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0793 - accuracy: 0.7004 - val_loss: 0.0784 - val_accuracy: 0.7044
# Epoch 11/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0756 - accuracy: 0.7003 - val_loss: 0.0769 - val_accuracy: 0.7042
# Epoch 12/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0729 - accuracy: 0.7002 - val_loss: 0.0740 - val_accuracy: 0.7042
# Epoch 13/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0714 - accuracy: 0.7004 - val_loss: 0.0764 - val_accuracy: 0.7042
# Epoch 14/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0707 - accuracy: 0.7005 - val_loss: 0.0723 - val_accuracy: 0.7044
# Epoch 15/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0693 - accuracy: 0.7005 - val_loss: 0.0711 - val_accuracy: 0.7044
# Epoch 16/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0681 - accuracy: 0.7009 - val_loss: 0.0728 - val_accuracy: 0.7044
# Epoch 17/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0675 - accuracy: 0.7010 - val_loss: 0.0748 - val_accuracy: 0.7044
# Epoch 18/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0671 - accuracy: 0.7012 - val_loss: 0.0688 - val_accuracy: 0.7047
# Epoch 19/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0662 - accuracy: 0.7013 - val_loss: 0.0688 - val_accuracy: 0.7047
# Epoch 20/20
# 843/843 [==============================] - 3s 3ms/step - loss: 0.0657 - accuracy: 0.7015 - val_loss: 0.0683 - val_accuracy: 0.7047

# %%
#list all data in history
model.history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # History for accuracy and loss

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')

# %% [markdown]
# # Tuning of Hyperparameter

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim = 10, kernel_initializer = 'uniform', activation = 'relu'))
    model.add(Dense(8,  kernel_initializer = 'uniform', activation = 'relu'))
    model.add(Dense(1,  kernel_initializer = 'uniform', activation = 'linear'))
    
    adam = Adam(lr = 0.01)
    model.compile(loss = 'mse', optimizer = adam, metrics = ['accuracy'])
    return model

# %%
model_1 = KerasClassifier(build_fn = create_model,verbose = 0)
model_1
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19716\2847926054.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model_1 = KerasClassifier(build_fn = create_model,verbose = 0)

# %%
batch_size = [10,20,40]
epochs = [10,50,100]
param_grid = dict(batch_size = batch_size,epochs = epochs)

# %%
grid = GridSearchCV(estimator = model_1, param_grid = param_grid,cv = KFold(),verbose =5)
grid_result = grid.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ..........batch_size=10, epochs=10;, score=0.694 total time=  20.7s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END ..........batch_size=10, epochs=10;, score=0.947 total time=  22.3s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END ..........batch_size=10, epochs=10;, score=0.707 total time=  20.6s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END ..........batch_size=10, epochs=10;, score=0.697 total time=  20.2s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END ..........batch_size=10, epochs=10;, score=0.708 total time=  20.2s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END ..........batch_size=10, epochs=50;, score=0.694 total time= 1.6min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END ..........batch_size=10, epochs=50;, score=0.709 total time= 1.5min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END ..........batch_size=10, epochs=50;, score=0.964 total time= 1.5min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END ..........batch_size=10, epochs=50;, score=0.948 total time= 1.5min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END ..........batch_size=10, epochs=50;, score=0.708 total time= 1.6min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END .........batch_size=10, epochs=100;, score=0.949 total time= 3.2min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END .........batch_size=10, epochs=100;, score=0.709 total time= 2.7min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END .........batch_size=10, epochs=100;, score=0.953 total time= 2.4min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END .........batch_size=10, epochs=100;, score=0.697 total time= 2.4min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END .........batch_size=10, epochs=100;, score=0.708 total time= 2.4min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END ..........batch_size=20, epochs=10;, score=0.694 total time=   8.2s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END ..........batch_size=20, epochs=10;, score=0.921 total time=   8.4s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END ..........batch_size=20, epochs=10;, score=0.707 total time=   8.3s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END ..........batch_size=20, epochs=10;, score=0.951 total time=   8.2s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END ..........batch_size=20, epochs=10;, score=0.896 total time=   8.1s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END ..........batch_size=20, epochs=50;, score=0.947 total time=  38.7s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END ..........batch_size=20, epochs=50;, score=0.913 total time=  39.4s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END ..........batch_size=20, epochs=50;, score=0.897 total time=  41.0s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END ..........batch_size=20, epochs=50;, score=0.945 total time=  40.8s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END ..........batch_size=20, epochs=50;, score=0.708 total time=  37.7s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END .........batch_size=20, epochs=100;, score=0.946 total time= 1.3min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END .........batch_size=20, epochs=100;, score=0.709 total time= 1.2min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END .........batch_size=20, epochs=100;, score=0.952 total time= 1.2min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END .........batch_size=20, epochs=100;, score=0.946 total time= 1.2min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END .........batch_size=20, epochs=100;, score=0.930 total time= 1.2min
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END ..........batch_size=40, epochs=10;, score=0.917 total time=   4.7s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END ..........batch_size=40, epochs=10;, score=0.934 total time=   4.5s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END ..........batch_size=40, epochs=10;, score=0.956 total time=   5.1s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END ..........batch_size=40, epochs=10;, score=0.936 total time=   4.6s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END ..........batch_size=40, epochs=10;, score=0.708 total time=   4.7s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END ..........batch_size=40, epochs=50;, score=0.948 total time=  19.7s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END ..........batch_size=40, epochs=50;, score=0.943 total time=  19.0s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END ..........batch_size=40, epochs=50;, score=0.939 total time=  19.4s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END ..........batch_size=40, epochs=50;, score=0.939 total time=  19.6s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END ..........batch_size=40, epochs=50;, score=0.941 total time=  19.0s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 1/5] END .........batch_size=40, epochs=100;, score=0.961 total time=  37.5s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 2/5] END .........batch_size=40, epochs=100;, score=0.947 total time=  38.1s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 3/5] END .........batch_size=40, epochs=100;, score=0.946 total time=  37.1s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 4/5] END .........batch_size=40, epochs=100;, score=0.948 total time=  38.4s
# C:\Users\Lenovo\Python\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# [CV 5/5] END .........batch_size=40, epochs=100;, score=0.924 total time=  37.9s
